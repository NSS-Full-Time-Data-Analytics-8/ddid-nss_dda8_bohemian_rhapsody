# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import datetime as dt
# %matplotlib inline

# %%
aeps_17_22 = pd.read_excel('../data/AEPSi_Data.xlsx' , 2, nrows =17927)
aeps_17_22
# Out:
#        Child ID                                       Program Name  AEPSi ID  \
# 0            11                                     Signal Centers    722747
# 1         10724    Little Tennessee Valley Educational Cooperative    707878
# 2         10724    Little Tennessee Valley Educational Cooperative    707878
# 3         11112                                               SRVS    665041
# 4         11112                                               SRVS    665041
# ...         ...                                                ...       ...
# 17922  525580\t                                     Signal Centers    728111
# 17923  525665\t                                        Kids Putnam    726427
# 17924  527045\t  Support Solutions of the Midsouth(formerly CS ...    728551
# 17925  527292\t                                              Waves    728028
# 17926   i527999         Tennessee Technological University-BRIDGES    728069
#
# ...

# %%
aeps_17_22 = aeps_17_22.astype({'Child ID':str})

# %%
aeps_17_22['Child ID'] = aeps_17_22['Child ID'].str.replace('\t','')

# %%
aeps_17_22['Child ID'] = aeps_17_22['Child ID'].str.replace('i','')

# %%
aeps_17_22.loc[:,['Child ID', 'AEPSi ID', 'AssessID', 'AEPS Level', 'DOB', 'Gender', 'Dev Status', 'Test Date', 'Examiner', 'Chron Age', 'TEIS Point of Entry Office (POE)', 'ESL', 'County of Residence', 
'fm_B4.0',
'fm_B5.0',
'cog_D2.0',
'cog_E2.0',
'cog_E4.0',
'cog_F1.0',
'cog_G1.0',
'cog_G2.0',
'cog_G3.0',
'cog_G4.0',
'cog_G5.0',
'cog_G6.0',
'sc_B1.0',
'sc_B2.0',
'sc_D1.0',
'sc_D2.0',
'sc_D3.0',
'FM Possible Score',
'Cog Possible Score',
'SC Possible Score']]
# Out:
#       Child ID  AEPSi ID  AssessID  AEPS Level                  DOB Gender  \
# 0           11    722747  10584304           1  2020-02-02 00:00:00      M
# 1        10724    707878  10575064           1  2021-07-30 00:00:00      F
# 2        10724    707878  10589703           1  2021-07-30 00:00:00      F
# 3        11112    665041  10535282           1  2020-04-27 00:00:00      F
# 4        11112    665041  10503223           1  2020-04-27 00:00:00      F
# ...        ...       ...       ...         ...                  ...    ...
# 17922   525580    728111  10599244           1  2020-09-23 00:00:00      M
# 17923   525665    726427  10595337           1  2020-09-08 00:00:00      F
# 17924   527045    728551  10599956           1  2020-06-29 00:00:00      M
# 17925   527292    728028  10599127           1  2020-11-23 00:00:00      F
# 17926   527999    728069  10599192           1  2021-07-23 00:00:00      F
#
#                      Dev Status            Test Date  \
# ...

# %%
eco_exit_20_21 = pd.read_excel('../data/AEPSi_Data.xlsx' , 4, nrows = 8441)
eco_exit_20_21
# Out:
#      DISTRICT  CHILD_ID ECO_Entry_DATE  Ent SOCIAL_SCALE  Ent KNOWLEDGE_SCALE  \
# 0          ET    456849     2019-04-24               3.0                  5.0
# 1          ET    490916            NaT               NaN                  NaN
# 2          ET    426757     2019-03-13               2.0                  3.0
# 3          ET    480611     2020-05-28               2.0                  5.0
# 4          ET    492863            NaT               NaN                  NaN
# ...       ...       ...            ...               ...                  ...
# 8436       FT    422823            NaT               NaN                  NaN
# 8437       UC    457024     2019-04-05               5.0                  5.0
# 8438       UC    496398            NaT               NaN                  NaN
# 8439       UC    486316            NaT               NaN                  NaN
# 8440       UC    472195            NaT               NaN                  NaN
#
# ...

# %%
eco_exit_21 = eco_exit_20_21.loc[:,['DISTRICT','CHILD_ID','ECO_Entry_DATE','Ent SOCIAL_SCALE','Ent KNOWLEDGE_SCALE','Ent APPROPRIATE_ACTION_SCALE','ECO_Exit_DATE','Exit SOCIAL_SCALE','Exit KNOWLEDGE_SCALE','Exit APPROPRIATE_ACTION_SCALE','Exit IS_SOCIAL_PROGRESS','Exit IS_KNOWLEDGE_PROGRESS','Exit IS_APPROPRIATE_ACTION_PROGRESS','Initial IFSP Date','Exit Reason','Exit Date','OC2 - a','OC2 - b', 'OC2 - c','OC2 - d', 'OC2 - e',
'OC2 Data Check']]
eco_exit_21
# Out:
#      DISTRICT  CHILD_ID ECO_Entry_DATE  Ent SOCIAL_SCALE  Ent KNOWLEDGE_SCALE  \
# 0          ET    456849     2019-04-24               3.0                  5.0
# 1          ET    490916            NaT               NaN                  NaN
# 2          ET    426757     2019-03-13               2.0                  3.0
# 3          ET    480611     2020-05-28               2.0                  5.0
# 4          ET    492863            NaT               NaN                  NaN
# ...       ...       ...            ...               ...                  ...
# 8436       FT    422823            NaT               NaN                  NaN
# 8437       UC    457024     2019-04-05               5.0                  5.0
# 8438       UC    496398            NaT               NaN                  NaN
# 8439       UC    486316            NaT               NaN                  NaN
# 8440       UC    472195            NaT               NaN                  NaN
#
# ...

# %%
eco_exit_21 = eco_exit_21.rename(columns={'Exit IS_SOCIAL_PROGRESS':'ExitIS_SOCIAL_PROGRESS','Exit IS_KNOWLEDGE_PROGRESS':'ExitIS_KNOWLEDGE_PROGRESS','Exit IS_APPROPRIATE_ACTION_PROGRESS':'ExitIS_APPROPRIATE_ACTION_PROGRESS'})

# %%
eco_exit_21_22 = pd.read_excel('../data/AEPSi_Data.xlsx' , 6, nrows = 8632)
eco_exit_21_22
# Out:
#      DISTRICT  CHILD_ID ECO_Entry_DATE  Ent SOCIAL_SCALE  Ent KNOWLEDGE_SCALE  \
# 0          ET    500335     2021-04-23               5.0                  3.0
# 1          ET    479453     2020-03-23               7.0                  7.0
# 2          ET    510663            NaT               NaN                  NaN
# 3          ET    452482     2019-01-31               2.0                  3.0
# 4          ET    506507            NaT               NaN                  NaN
# ...       ...       ...            ...               ...                  ...
# 8627       UC    485978     2020-08-19               1.0                  3.0
# 8628       UC    488802     2020-09-21               4.0                  4.0
# 8629       UC    516136            NaT               NaN                  NaN
# 8630       UC    490688     2020-10-27               4.0                  5.0
# 8631       UC    514216            NaT               NaN                  NaN
#
# ...

# %%
eco_exit_22 = eco_exit_21_22.loc[:,['DISTRICT','CHILD_ID','ECO_Entry_DATE','Ent SOCIAL_SCALE','Ent KNOWLEDGE_SCALE','Ent APPROPRIATE_ACTION_SCALE','ECO_Exit_DATE','Exit SOCIAL_SCALE','Exit KNOWLEDGE_SCALE','Exit APPROPRIATE_ACTION_SCALE','ExitIS_SOCIAL_PROGRESS','ExitIS_KNOWLEDGE_PROGRESS','ExitIS_APPROPRIATE_ACTION_PROGRESS','Initial IFSP Date','Exit Reason','Exit Date'
]]
eco_exit_22
# Out:
#      DISTRICT  CHILD_ID ECO_Entry_DATE  Ent SOCIAL_SCALE  Ent KNOWLEDGE_SCALE  \
# 0          ET    500335     2021-04-23               5.0                  3.0
# 1          ET    479453     2020-03-23               7.0                  7.0
# 2          ET    510663            NaT               NaN                  NaN
# 3          ET    452482     2019-01-31               2.0                  3.0
# 4          ET    506507            NaT               NaN                  NaN
# ...       ...       ...            ...               ...                  ...
# 8627       UC    485978     2020-08-19               1.0                  3.0
# 8628       UC    488802     2020-09-21               4.0                  4.0
# 8629       UC    516136            NaT               NaN                  NaN
# 8630       UC    490688     2020-10-27               4.0                  5.0
# 8631       UC    514216            NaT               NaN                  NaN
#
# ...

# %%
aeps_17_22.dtypes
# Out:
# Child ID           object
# Program Name       object
# AEPSi ID            int64
# AssessID            int64
# State              object
#                    ...
# SC Cutoff         float64
# SC Result          object
# Soc Goal Score    float64
# Soc Cutoff        float64
# Soc Result         object
# Length: 307, dtype: object

# %%
no_infoaeps = aeps_17_22.columns
sns.heatmap(aeps_17_22[no_infoaeps].isnull())
# Out:
# <AxesSubplot:>

# %%
no_info21 = eco_exit_21.columns
sns.heatmap(eco_exit_21[no_info21].isnull())
# Out:
# <AxesSubplot:>

# %%
no_info22 = eco_exit_22.columns
sns.heatmap(eco_exit_22[no_info22].isnull())
# Out:
# <AxesSubplot:>

# %%
eco_combine= pd.concat([eco_exit_21, eco_exit_22], axis=0)

# %%
eco_combine_desc = eco_combine.describe()
eco_combine_desc
# Out:
#             CHILD_ID  Ent SOCIAL_SCALE  Ent KNOWLEDGE_SCALE  \
# count   17073.000000      11121.000000         11121.000000
# mean   479006.579043          3.180649             3.563259
# std     21879.268785          1.899689             1.692656
# min    420959.000000          1.000000             1.000000
# 25%    465176.000000          2.000000             2.000000
# 50%    481730.000000          3.000000             4.000000
# 75%    494962.000000          5.000000             5.000000
# max    528675.000000          7.000000             7.000000
#
#        Ent APPROPRIATE_ACTION_SCALE  Exit SOCIAL_SCALE  Exit KNOWLEDGE_SCALE  \
# count                  11121.000000       11121.000000          11121.000000
# mean                       3.883823           4.736624              4.230645
# std                        2.149743           2.137907              2.129896
# min                        1.000000           1.000000              1.000000
# ...

# %%
fig, ax = plt.subplots(figsize=(6, 6))

eco_corr = eco_exit_22.corr()

cmap = sns.diverging_palette(220, 10, as_cmap=True)

mask = np.zeros_like(eco_corr, dtype=bool)
mask[np.triu_indices_from(mask)] = True

sns.heatmap(eco_corr, cmap=cmap, mask = mask, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5});

# %%
eco_combine.rename(columns={'Ent SOCIAL_SCALE':'Ent_SOCIAL_SCALE','Ent KNOWLEDGE_SCALE':'Ent_KNOWLEDGE_SCALE', 'Ent APPROPRIATE_ACTION_SCALE':'Ent_APPROPRIATE_ACTION_SCALE', 'Exit SOCIAL_SCALE' : 'Exit_SOCIAL_SCALE', 'Exit KNOWLEDGE_SCALE':'Exit_KNOWLEDGE_SCALE', 'Exit APPROPRIATE_ACTION_SCALE':'Exit_APPROPRIATE_ACTION_SCALE', 'Initial IFSP Date': 'Initial_IFSP_Date', 'Exit Reason':'Exit_Reason','Exit Date':'Exit_Date', 'OC2 - a':'OC2_a','OC2 - b': 'OC2_b','OC2 - c':'OC2_c','OC2 - d':'OC2_d','OC2 - e':'OC2_e', 'OC2 Data Check':'OC2_Data_Check' })
# Out:
#      DISTRICT  CHILD_ID ECO_Entry_DATE  Ent_SOCIAL_SCALE  Ent_KNOWLEDGE_SCALE  \
# 0          ET    456849     2019-04-24               3.0                  5.0
# 1          ET    490916            NaT               NaN                  NaN
# 2          ET    426757     2019-03-13               2.0                  3.0
# 3          ET    480611     2020-05-28               2.0                  5.0
# 4          ET    492863            NaT               NaN                  NaN
# ...       ...       ...            ...               ...                  ...
# 8627       UC    485978     2020-08-19               1.0                  3.0
# 8628       UC    488802     2020-09-21               4.0                  4.0
# 8629       UC    516136            NaT               NaN                  NaN
# 8630       UC    490688     2020-10-27               4.0                  5.0
# 8631       UC    514216            NaT               NaN                  NaN
#
# ...

# %%
import matplotlib.pyplot as plt
  

left = ['ECO_Entry_DATE','Ent_KNOWLEDGE_SCALE','Ent_SOCIAL_SCALE','ECO_Exit_DATE','Exit_SOCIAL_SCALE' ]
  
height = [2, 4, 6, 8, 10]
  
tick_label = ['ECO_Entry_DATE','Ent_KNOWLEDGE_SCALE','Ent_SOCIAL_SCALE','ECO_Exit_DATE','Exit_SOCIAL_SCALE']

plt.bar(left, height, tick_label = tick_label,
        width = 0.5, color = ['red', 'green','blue', 'yellow', 'orange'])

plt.xlabel('Entry')

plt.ylabel('Exit')

plt.title('Entry & Exit')
  
plt.show()

# %%
ges = ['ECO_Entry_DATE','Ent_KNOWLEDGE_SCALE','Ent_SOCIAL_SCALE','ECO_Exit_DATE','Exit_SOCIAL_SCALE']
  
range = (0, 100)
bins = 10  
  
plt.hist(eco_combine, bins, range, color = 'green',
        histtype = 'bar', rwidth = 0.8)
  
plt.xlabel('Entry')

plt.ylabel('Exit')

plt.title('My histogram')
  
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/axis.py in convert_units(self, x)
#    1505         try:
# -> 1506             ret = self.converter.convert(x, self.units, self)
#    1507         except Exception as e:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/category.py in convert(value, unit, axis)
#      67         # force an update so it also does type checking
# ---> 68         unit.update(values)
#      69         return np.vectorize(unit._mapping.__getitem__, otypes=[float])(values)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/category.py in update(self, data)
#     226             # OrderedDict just iterates over unique values in data.
# --> 227             _api.check_isinstance((str, bytes), value=val)
#     228             if convertible:
#
# ...

# %%
low_outliers_2 = eco_combine_desc.loc['25%', 'Ent_APPROPRIATE_ACTION_SCALE']-(1.5 * (eco_combine_desc.loc['75%', 'Ent_APPROPRIATE_ACTION_SCALE']-eco_combine_desc.loc['25%', 'Ent_APPROPRIATE_ACTION_SCALE']))

# %%
print(len(eco_combine.loc[(eco_combine.Ent_APPROPRIATE_ACTION_SCALE < -12.5) | (eco_combine.years_played_sports > 23.5)]))
sns.boxplot(eco_combine.years_played_sports)
